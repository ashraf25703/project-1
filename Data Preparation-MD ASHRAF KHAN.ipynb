# %%
# Importing necessary libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the file.
df = pd.read_excel("C:/Users/asd/Downloads/Mentornship/Online Retail.xlsx")

# %%
# Analysing the columns.
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# Checking data types.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
# Descriptive statistics.
df.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  541909.000000                         541909  541909.000000
# mean        9.552250  2011-07-04 13:34:57.156386048       4.611114
# min    -80995.000000            2010-12-01 08:26:00  -11062.060000
# 25%         1.000000            2011-03-28 11:34:00       1.250000
# 50%         3.000000            2011-07-19 17:17:00       2.080000
# 75%        10.000000            2011-10-19 11:27:00       4.130000
# max     80995.000000            2011-12-09 12:50:00   38970.000000
# std       218.081158                            NaN      96.759853
#
#           CustomerID
# count  406829.000000
# mean    15287.690570
# min     12346.000000
# 25%     13953.000000
# 50%     15152.000000
# 75%     16791.000000
# max     18287.000000
# std      1713.600303

# %%
# Checking transactions distribution
df['Quantity'].describe()
sns.boxplot(x=df['Quantity'])
# Out:
# <Axes: xlabel='Quantity'>

# %%
df['UnitPrice'].describe()
sns.boxplot(x=df['UnitPrice'])
# Out:
# <Axes: xlabel='UnitPrice'>

# %%
# Cheking total null values.
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# checking missing percentage by total rows.
missing_percent = df.isnull().sum()/len(df)*100
missing_percent.sort_values(ascending=False)
# Out:
# CustomerID     24.926694
# Description     0.268311
# InvoiceNo       0.000000
# StockCode       0.000000
# Quantity        0.000000
# InvoiceDate     0.000000
# UnitPrice       0.000000
# Country         0.000000
# dtype: float64

# %%
# Removing rows without customer id
df = df.dropna(subset=['CustomerID'])

# Filling  missing description as 'unknown product'.
df['Description'] = df['Description'].fillna('Unknown Product')

# Removing duplicate rows.
df = df.drop_duplicates()

# Removing invalid transactions.
df = df[df['Quantity'] > 0]
df = df[df['UnitPrice'] > 0]

# Correcting datatypes.
df['CustomerID'] = df['CustomerID'].astype(int)
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'], errors='coerce')

# Removing invalid dates.
df = df.dropna(subset=['InvoiceDate'])

# %%
# Creating new numeric feature.
df['TotalPrice'] = df['Quantity'] * df['UnitPrice']

print("\nColumns before encoding:", df.columns.tolist())

if 'Country' in df.columns:
    df = pd.get_dummies(df, columns=['Country'])
    print("Country column encoded")
else:
    print("Country column already encoded or missing")


# Standardize numeric features.
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df[['Quantity','UnitPrice','TotalPrice']] = scaler.fit_transform(
    df[['Quantity','UnitPrice','TotalPrice']]
)
# Out:
# Columns before encoding: ['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate', 'UnitPrice', 'CustomerID', 'Country', 'TotalPrice']
# Country column encoded

# %%
# Creating single datetime feature.
df['DateTime_Feature'] = df['InvoiceDate'].astype('int64') // 10**9


# Removing non-ML columns.
columns_to_drop = ['InvoiceNo','StockCode','Description','InvoiceDate']
df_ml = df.drop([col for col in columns_to_drop if col in df.columns], axis=1)

# %%
# Printing the final dataset(Preview).
print("\nFINAL DATASET PREVIEW")
print(df_ml.head())

print("\nFINAL INFO")
print(df_ml.info())
# Out:
# FINAL DATASET PREVIEW
#    Quantity  UnitPrice  CustomerID  TotalPrice  Country_Australia  \
# 0 -0.039446  -0.025893       17850   -0.023566              False
# 1 -0.039446   0.011873       17850   -0.007366              False
# 2 -0.028365  -0.016901       17850   -0.002030              False
# 3 -0.039446   0.011873       17850   -0.007366              False
# 4 -0.039446   0.011873       17850   -0.007366              False
#
#    Country_Austria  Country_Bahrain  Country_Belgium  Country_Brazil  \
# 0            False            False            False           False
# 1            False            False            False           False
# 2            False            False            False           False
# 3            False            False            False           False
# 4            False            False            False           False
#
#    Country_Canada  ...  Country_Saudi Arabia  Country_Singapore  \
# 0           False  ...                 False              False
# 1           False  ...                 False              False
# 2           False  ...                 False              False
# 3           False  ...                 False              False
# 4           False  ...                 False              False
#
#    Country_Spain  Country_Sweden  Country_Switzerland  Country_USA  \
# 0          False           False                False        False
# 1          False           False                False        False
# 2          False           False                False        False
# 3          False           False                False        False
# 4          False           False                False        False
#
#    Country_United Arab Emirates  Country_United Kingdom  Country_Unspecified  \
# 0                         False                    True                False
# 1                         False                    True                False
# 2                         False                    True                False
# 3                         False                    True                False
# 4                         False                    True                False
#
#    DateTime_Feature
# 0        1291191960
# 1        1291191960
# 2        1291191960
# 3        1291191960
# 4        1291191960
#
# [5 rows x 42 columns]
#
# FINAL INFO
# <class 'pandas.core.frame.DataFrame'>
# Index: 392692 entries, 0 to 541908
# Data columns (total 42 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Quantity                      392692 non-null  float64
#  1   UnitPrice                     392692 non-null  float64
#  2   CustomerID                    392692 non-null  int64
#  3   TotalPrice                    392692 non-null  float64
#  4   Country_Australia             392692 non-null  bool
#  5   Country_Austria               392692 non-null  bool
#  6   Country_Bahrain               392692 non-null  bool
#  7   Country_Belgium               392692 non-null  bool
#  8   Country_Brazil                392692 non-null  bool
#  9   Country_Canada                392692 non-null  bool
#  10  Country_Channel Islands       392692 non-null  bool
#  11  Country_Cyprus                392692 non-null  bool
#  12  Country_Czech Republic        392692 non-null  bool
#  13  Country_Denmark               392692 non-null  bool
#  14  Country_EIRE                  392692 non-null  bool
#  15  Country_European Community    392692 non-null  bool
#  16  Country_Finland               392692 non-null  bool
#  17  Country_France                392692 non-null  bool
#  18  Country_Germany               392692 non-null  bool
#  19  Country_Greece                392692 non-null  bool
#  20  Country_Iceland               392692 non-null  bool
#  21  Country_Israel                392692 non-null  bool
#  22  Country_Italy                 392692 non-null  bool
#  23  Country_Japan                 392692 non-null  bool
#  24  Country_Lebanon               392692 non-null  bool
#  25  Country_Lithuania             392692 non-null  bool
#  26  Country_Malta                 392692 non-null  bool
#  27  Country_Netherlands           392692 non-null  bool
#  28  Country_Norway                392692 non-null  bool
#  29  Country_Poland                392692 non-null  bool
#  30  Country_Portugal              392692 non-null  bool
#  31  Country_RSA                   392692 non-null  bool
#  32  Country_Saudi Arabia          392692 non-null  bool
#  33  Country_Singapore             392692 non-null  bool
#  34  Country_Spain                 392692 non-null  bool
#  35  Country_Sweden                392692 non-null  bool
#  36  Country_Switzerland           392692 non-null  bool
#  37  Country_USA                   392692 non-null  bool
#  38  Country_United Arab Emirates  392692 non-null  bool
#  39  Country_United Kingdom        392692 non-null  bool
#  40  Country_Unspecified           392692 non-null  bool
#  41  DateTime_Feature              392692 non-null  int64
# dtypes: bool(37), float64(3), int64(2)
# memory usage: 31.8 MB
# None
